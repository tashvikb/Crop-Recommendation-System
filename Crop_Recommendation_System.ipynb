# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
crop_recommend = pd.read_csv('/content/Crop_recommendation.csv')

# %%
crop_recommend.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
crop_recommend.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %%
crop_recommend.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
crop_recommend.duplicated().sum()
# Out:
# 0

# %%
crop_recommend.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
corr = crop_recommend.corr()
corr
# Out:
# <ipython-input-8-8c7945e606f3>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = crop_recommend.corr()
#                     N         P         K  temperature  humidity        ph  \
# N            1.000000 -0.231460 -0.140512     0.026504  0.190688  0.096683
# P           -0.231460  1.000000  0.736232    -0.127541 -0.118734 -0.138019
# K           -0.140512  0.736232  1.000000    -0.160387  0.190859 -0.169503
# temperature  0.026504 -0.127541 -0.160387     1.000000  0.205320 -0.017795
# humidity     0.190688 -0.118734  0.190859     0.205320  1.000000 -0.008483
# ph           0.096683 -0.138019 -0.169503    -0.017795 -0.008483  1.000000
# rainfall     0.059020 -0.063839 -0.053461    -0.030084  0.094423 -0.109069
#
#              rainfall
# N            0.059020
# P           -0.063839
# ...

# %%
sns.heatmap(corr,annot=True,cbar=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
crop_recommend['label'].value_counts()
# Out:
# rice           100
# maize          100
# jute           100
# cotton         100
# coconut        100
# papaya         100
# orange         100
# apple          100
# muskmelon      100
# watermelon     100
# grapes         100
# mango          100
# banana         100
# pomegranate    100
# lentil         100
# blackgram      100
# mungbean       100
# mothbeans      100
# pigeonpeas     100
# kidneybeans    100
# chickpea       100
# coffee         100
# Name: label, dtype: int64

# %%
sns.displot(crop_recommend['N'],kde='True')
plt.show()

# %%
sns.displot(crop_recommend['P'],kde='True')
plt.show()

# %%
sns.displot(crop_recommend['K'],kde='True')
plt.show()

# %%
sns.displot(crop_recommend['temperature'],kde='True')
plt.show()

# %%
plt.figure(figsize=(20,20))
ax=sns.catplot(data=crop_recommend,x='label',y='temperature',jitter=False)
ax.set_xticklabels(rotation=90)
plt.tight_layout()
plt.show()

# %%
crop_dict={
    'rice' : 1,
    'maize' : 2,
    'jute'  : 3,
    'cotton' : 4,
    'coconut' :5,
    'papaya' :6,
    'orange'   :7,
    'apple'   :8,
    'muskmelon' :9,
    'watermelon' :10,
    'grapes'   :11,
    'mango'   :12,
    'banana'   :13,
    'pomegranate' :14,
    'lentil'      :15,
    'blackgram'  :16,
    'mungbean'  :17,
    'pigeonpeas' :18,
    'kidneybeans' :19,
    'chickpea'     :20,
    'coffee':21,
    'mothbeans':22
}

# %%
crop_recommend['crop_num']=crop_recommend['label'].map(crop_dict)

# %%
crop_recommend['crop_num'].value_counts()
# Out:
# 1     100
# 2     100
# 3     100
# 4     100
# 5     100
# 6     100
# 7     100
# 8     100
# 9     100
# 10    100
# 11    100
# 12    100
# 13    100
# 14    100
# 15    100
# 16    100
# 17    100
# 22    100
# 18    100
# 19    100
# 20    100
# 21    100
# Name: crop_num, dtype: int64

# %%
crop_recommend.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label  crop_num
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice         1
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice         1
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice         1
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice         1
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice         1

# %%
crop_recommend.drop('label',axis=1,inplace=True)

# %%
crop_recommend.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall  crop_num
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536         1
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537         1
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248         1
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034         1
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340         1

# %% [markdown]
# **Training and Testing**

# %%
x=crop_recommend.drop('crop_num',axis=1)
y=crop_recommend['crop_num']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train.shape
# Out:
# (1760, 7)

# %%
x_test.shape
# Out:
# (440, 7)

# %%
from sklearn.preprocessing import MinMaxScaler

ms = MinMaxScaler()
x_train = ms.fit_transform(x_train)
x_test = ms.fit_transform(x_test)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)

# %%
x_train
# Out:
# array([[-0.64463185,  2.00512125,  2.96466347, ...,  0.86301256,
#         -0.4785779 ,  0.23692732],
#        [ 0.81334894, -0.52889759, -0.2035231 , ...,  0.7381018 ,
#         -0.18240887,  0.84590226],
#        [ 1.05634574,  0.1649409 , -0.26219322, ...,  0.82317986,
#          0.82415091,  1.29625399],
#        ...,
#        [-0.42863469,  0.31577536, -0.65332736, ..., -0.36751109,
#          0.03555503, -0.61777686],
#        [-0.32063612,  0.34594225, -0.4968737 , ..., -0.11470255,
#          1.59909782, -1.13413007],
#        [-0.99562722, -0.95123406, -0.7706676 , ...,  0.880759  ,
#          0.09231399,  0.1609325 ]])

# %%
x_test
# Out:
# array([[ 1.5330379 , -1.19845492,  0.05931592, ...,  0.74178647,
#         -0.04281651, -0.8002622 ],
#        [ 1.14801268, -1.26041605, -0.02301533, ...,  0.64587051,
#         -0.13307527, -1.01060703],
#        [-0.969626  ,  2.11646533,  3.20848624, ...,  0.5691153 ,
#         -0.3556926 , -0.52567594],
#        ...,
#        [ 1.86305951,  0.10272873, -0.66108252, ...,  0.27583543,
#          1.09783758, -0.25393588],
#        [-0.61210259,  0.35057324, -0.53758564, ..., -0.09092708,
#          1.30878994, -0.54037021],
#        [-0.50209538,  2.3952904 ,  3.10557218, ...,  0.96288965,
#         -1.08135386,  0.31977697]])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import ExtraTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score

# create instances of all models
models = {
    'Logistic Regression': LogisticRegression(),
    'Naive Bayes': GaussianNB(),
    'Support Vector Machine': SVC(),
    'K-Nearest Neighbors': KNeighborsClassifier(),
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(),
    'Bagging': BaggingClassifier(),
    'AdaBoost': AdaBoostClassifier(),
    'Gradient Boosting': GradientBoostingClassifier(),
    'Extra Trees': ExtraTreeClassifier(),
}


for name, md in models.items():
    md.fit(x_train,y_train)
    ypred = md.predict(x_test)

    print(f"{name}  with accuracy : {accuracy_score(y_test,ypred)}")
# Out:
# Logistic Regression  with accuracy : 0.9659090909090909
# Naive Bayes  with accuracy : 0.990909090909091
# Support Vector Machine  with accuracy : 0.9818181818181818
# K-Nearest Neighbors  with accuracy : 0.9818181818181818
# Decision Tree  with accuracy : 0.9863636363636363
# Random Forest  with accuracy : 0.9840909090909091
# Bagging  with accuracy : 0.975
# AdaBoost  with accuracy : 0.17272727272727273
# Gradient Boosting  with accuracy : 0.9613636363636363
# Extra Trees  with accuracy : 0.8613636363636363

# %%
gnb = GaussianNB()
gnb.fit(x_train,y_train)
ypred = gnb.predict(x_test)
accuracy_score(y_test,ypred)
# Out:
# 0.990909090909091

# %%
def recommendation(N,P,k,temperature,humidity,ph,rainfal):
    features = np.array([[N,P,k,temperature,humidity,ph,rainfal]])
    transformed_features = ms.fit_transform(features)
    transformed_features = scaler.fit_transform(transformed_features)
    prediction = gnb.predict(transformed_features)

    return prediction[0]

# %%
N = 40
P = 50
k = 50
temperature = 40.0
humidity = 20
ph = 100
rainfall = 100

predict = recommendation(N,P,k,temperature,humidity,ph,rainfall)

# %%
print(predict)
# Out:
# 3

# %%
crop_dict = {1: "Rice", 2: "Maize", 3: "Jute", 4: "Cotton", 5: "Coconut", 6: "Papaya", 7: "Orange",
                 8: "Apple", 9: "Muskmelon", 10: "Watermelon", 11: "Grapes", 12: "Mango", 13: "Banana",
                 14: "Pomegranate", 15: "Lentil", 16: "Blackgram", 17: "Mungbean", 18: "Mothbeans",
                 19: "Pigeonpeas", 20: "Kidneybeans", 21: "Chickpea", 22: "Coffee"}

if predict in crop_dict:
    crop = crop_dict[predict]
    print("{} is a best crop to be cultivated ".format(crop))
else:
    print("Sorry are not able to recommend a proper crop for this environment")
# Out:
# Jute is a best crop to be cultivated

# %%
import pickle
pickle.dump(gnb,open('model.pkl','wb'))
pickle.dump(ms,open('minmaxscaler.pkl','wb'))
pickle.dump(scaler,open('standscaler.pkl','wb'))
